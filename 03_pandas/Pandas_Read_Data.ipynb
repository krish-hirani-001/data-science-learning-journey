# %% [markdown]
# # Pandas Read Data Practice (Question + Answer Format)

# %% [markdown]
# ## Question
# 1. Read `students.csv` and display all records.

# %%
import pandas as pd
df=pd.read_csv('stud.csv')
df
# Out:
#    StudentID   Name  Age  Gender Course  Marks       City
# 0        101   Amit   20    Male    BCA     85     Rajkot
# 1        102  Priya   21  Female  BScIT     92  Ahmedabad
# 2        103  Rahul   22    Male   BCom     78      Surat
# 3        104   Neha   20  Female  BScIT     88     Rajkot
# 4        105  Karan   23    Male    BCA     67   Vadodara
# 5        106  Pooja   21  Female  BScIT     95  Ahmedabad
# 6        107  Vikas   22    Male    BCA     73      Surat
# 7        108   Riya   20  Female   BCom     81     Rajkot
# 8        109  Arjun   21    Male  BScIT     89   Vadodara
# 9        110  Sneha   22  Female    BCA     91  Ahmedabad

# %% [markdown]
# ## Question
# 2. Display only the `name` and `age` columns from `students.csv`.

# %%
df=pd.read_csv('stud.csv',usecols=['Name','Age'])
df
# Out:
#     Name  Age
# 0   Amit   20
# 1  Priya   21
# 2  Rahul   22
# 3   Neha   20
# 4  Karan   23
# 5  Pooja   21
# 6  Vikas   22
# 7   Riya   20
# 8  Arjun   21
# 9  Sneha   22

# %% [markdown]
# ## Question
# 3. Read the first 3 rows from a CSV file.

# %%
df=pd.read_csv('stud.csv',nrows=3)
df
# Out:
#    StudentID   Name  Age  Gender Course  Marks       City
# 0        101   Amit   20    Male    BCA     85     Rajkot
# 1        102  Priya   21  Female  BScIT     92  Ahmedabad
# 2        103  Rahul   22    Male   BCom     78      Surat

# %% [markdown]
# ## Question
# 4. Read `students.xlsx` and display the data.

# %%
df=pd.read_excel('students.xlsx')
df
# Out:
#    id   name  age       city
# 0   1  Krish   20     Rajkot
# 1   2  Rahul   21  Ahmedabad
# 2   3  Priya   19      Surat

# %% [markdown]
# ## Question
# 5. Read only `Sheet2` from an Excel file.

# %%
df=pd.read_excel('students.xlsx', sheet_name="Sheet2")
df
# Out:
#    id  course  marks
# 0   1  Python     85
# 1   2  Pandas     90
# 2   3   NumPy     88

# %% [markdown]
# ## Question
# 6. Read `students.json` and display all records.

# %%
df=pd.read_json('students.json')
df
# Out:
#    id   name  age       city
# 0   1  Krish   20     Rajkot
# 1   2  Rahul   21  Ahmedabad
# 2   3  Priya   19      Surat

# %% [markdown]
# ## Question
# 7. Read the first HTML table from `students.html`.

# %%
import pandas as pd

url = "https://www.w3schools.com/html/html_tables.asp"

tables = pd.read_html(url)

tables[0]
# Out:
#                         Company           Contact  Country
# 0           Alfreds Futterkiste      Maria Anders  Germany
# 1    Centro comercial Moctezuma   Francisco Chang   Mexico
# 2                  Ernst Handel     Roland Mendel  Austria
# 3                Island Trading     Helen Bennett       UK
# 4  Laughing Bacchus Winecellars   Yoshi Tannamuri   Canada
# 5  Magazzini Alimentari Riuniti  Giovanni Rovelli    Italy

# %% [markdown]
# ## Question
# 8. Save a DataFrame to a Pickle file named `students.pkl`.

# %%
df=pd.read_csv('stud.csv')
df.to_pickle('student.pkl')

# %% [markdown]
# ## Question
# 9. Read data from `students.pkl` and display it.

# %%
df=pd.read_pickle('student.pkl')
df
# Out:
#    StudentID   Name  Age  Gender Course  Marks       City
# 0        101   Amit   20    Male    BCA     85     Rajkot
# 1        102  Priya   21  Female  BScIT     92  Ahmedabad
# 2        103  Rahul   22    Male   BCom     78      Surat
# 3        104   Neha   20  Female  BScIT     88     Rajkot
# 4        105  Karan   23    Male    BCA     67   Vadodara
# 5        106  Pooja   21  Female  BScIT     95  Ahmedabad
# 6        107  Vikas   22    Male    BCA     73      Surat
# 7        108   Riya   20  Female   BCom     81     Rajkot
# 8        109  Arjun   21    Male  BScIT     89   Vadodara
# 9        110  Sneha   22  Female    BCA     91  Ahmedabad

# %% [markdown]
# ## Question
# 10. Compare the shape (rows, columns) of data loaded from CSV and JSON files.

# %%
csv_sp=pd.read_csv('stud.csv')
json_sp=pd.read_json('students.json')
print("csv :",csv_sp.shape)
print("json :",json_sp.shape)
# Out:
# csv : (10, 7)
# json : (3, 4)
